# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame([[1,2,3,4],[5,6,7,8],[9,3,4,5],[4,5,7,5],[6,7,8,9],[7,4,6,5]],columns=['a','b','c','d'])

# %%
import numpy as np
import random as rd
N = 500
x = []
y = []
for i in range (1,N):
    x.append(i+rd.randint(1,5))
    y.append(i+rd.randint(-5,-1))
x = np.array(x)
y = np.array(y)

# %%
ax = sns.scatterplot(x=x, y=y)

# %%
sns.jointplot(x=x, y=y, kind="kde")

# %%
sns.jointplot(x='a', y="b", data=df1, kind="kde")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-11bdcda75dde> in <module>
# ----> 1 sns.jointplot(x='a', y="b", data=df1, kind="kde")
#
# NameError: name 'df1' is not defined

# %%
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="hex", color="k")

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.a, df.c, ax=ax)
sns.rugplot(df['a'], color="g", ax=ax)
sns.rugplot(df['c'], vertical=True, ax=ax);

# %%
g = sns.jointplot(x=df['a'], y=df['b'],kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
ax = sns.heatmap(df.corr())
print(df.corr())
# Out:
#           a         b         c         d
# a  1.000000  0.195615  0.201135  0.219578
# b  0.195615  1.000000  0.963952  0.908688
# c  0.201135  0.963952  1.000000  0.772881
# d  0.219578  0.908688  0.772881  1.000000
