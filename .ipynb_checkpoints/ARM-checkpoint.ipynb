# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('breast-cancer.csv')

# %%
from sqlalchemy import create_engine
from pandas.io import sql
engine = create_engine('sqlite:///:memory:')
df.to_sql('breast-cancer',engine)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
def ARMformat(a,b,tb):
    collect = []
    for x in df[a].unique():
        q = "SELECT "+b+" FROM "+tb+" WHERE "+a+"='"+x+"'"
        res = pd.read_sql_query(q,engine)
        res=res[b].unique()
        resclean = []
        for i in res:
            if i!=None:
                resclean.append(i)
        resmin = resclean[0:10] #terpaksa biar cepat saja
        collect.append(list(resmin))
    return collect

# %%
data = ARMformat('diagnosis','texture_mean','breast-cancer')
len(data)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#
# OperationalError: near "-": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-35-d57f6f649013> in <module>
# ----> 1 data = ARMformat('radius_mean','texture_mean','breast-cancer')
#       2 len(data)
#
# <ipython-input-34-a9c68abab17e> in ARMformat(a, b, tb)
#       3     for x in df[a].unique():
#       4         q = "SELECT "+b+" FROM "+tb+" WHERE "+a+"="+str(x)
# ----> 5         res = pd.read_sql_query(q,engine)
#       6         res=res[b].unique()
#       7         resclean = []
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1097         args = _convert_params(sql, params)
#    1098
# -> 1099         result = self.execute(*args)
#    1100         columns = result.keys()
#    1101
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     988     def execute(self, *args, **kwargs):
#     989         """Simple passthrough to SQLAlchemy connectable"""
# --> 990         return self.connectable.execute(*args, **kwargs)
#     991
#     992     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2180
#    2181         connection = self._contextual_connect(close_with_result=True)
# -> 2182         return connection.execute(statement, *multiparams, **params)
#    2183
#    2184     def scalar(self, statement, *multiparams, **params):
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     974         """
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#     978             meth = object_._execute_on_connection
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1147             parameters,
#    1148             statement,
# -> 1149             parameters,
#    1150         )
#    1151         if self._has_events or self.engine._has_events:
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1244                 if not evt_handled:
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#    1248         except BaseException as e:
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579
#     580     def do_execute(self, cursor, statement, parameters, context=None):
# --> 581         cursor.execute(statement, parameters)
#     582
#     583     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) near "-": syntax error
# [SQL: SELECT texture_mean FROM breast-cancer WHERE radius_mean=17.99]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
i = 0
pre = df['Platform'].unique()
for dt in data:
    print(pre[i],dt,"\n")
    i+=1
# Out:
# Wii ['Nintendo', 'Ubisoft', 'Sega', '505 Games', 'LucasArts', 'Activision', 'Take-Two Interactive', 'Electronic Arts', 'Warner Bros. Interactive Entertainment', 'Disney Interactive Studios']
#
# NES ['Nintendo', 'Palcom', 'Enix Corporation', 'Namco Bandai Games', 'Capcom', 'Konami Digital Entertainment', 'Hudson Soft', 'SquareSoft', 'Ocean', 'BPS']
#
# GB ['Nintendo', 'Eidos Interactive', 'Konami Digital Entertainment', 'Electronic Arts', 'Enix Corporation', 'Namco Bandai Games', 'Capcom', 'Activision', 'SquareSoft', 'Imagineer']
#
# DS ['Nintendo', '505 Games', 'Sega', 'LucasArts', 'Electronic Arts', 'Activision', 'Disney Interactive Studios', 'Warner Bros. Interactive Entertainment', 'Ubisoft', 'Square Enix']
#
# X360 ['Microsoft Game Studios', 'Take-Two Interactive', 'Activision', 'Bethesda Softworks', 'Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment', 'Capcom', 'Eidos Interactive', 'MTV Games']
#
# PS3 ['Take-Two Interactive', 'Activision', 'Sony Computer Entertainment', 'Electronic Arts', 'Bethesda Softworks', 'Ubisoft', 'Konami Digital Entertainment', 'Sony Computer Entertainment Europe', 'Warner Bros. Interactive Entertainment', 'Square Enix']
#
# PS2 ['Take-Two Interactive', 'Sony Computer Entertainment', 'Electronic Arts', 'Konami Digital Entertainment', 'Square Enix', 'Universal Interactive', 'RedOctane', 'Activision', 'Vivendi Games', 'Namco Bandai Games']
#
# SNES ['Nintendo', 'Capcom', 'SquareSoft', 'Enix Corporation', 'Acclaim Entertainment', 'Virgin Interactive', 'Square', 'Banpresto', 'Namco Bandai Games', 'ASCII Entertainment']
#
# GBA ['Nintendo', 'Namco Bandai Games', 'Atari', 'THQ', 'Konami Digital Entertainment', 'Sega', 'Vivendi Games', 'SquareSoft', 'Electronic Arts', 'Square Enix']
#
# 3DS ['Nintendo', 'Capcom', 'Level 5', 'Square Enix', 'GungHo', 'Sega', 'LucasArts', 'Marvelous Entertainment', 'Warner Bros. Interactive Entertainment', 'mixi, Inc']
#
# PS4 ['Activision', 'Take-Two Interactive', 'Electronic Arts', 'Bethesda Softworks', 'Sony Computer Entertainment', 'Ubisoft', 'Sony Computer Entertainment Europe', 'Warner Bros. Interactive Entertainment', 'Namco Bandai Games', 'Konami Digital Entertainment']
#
# N64 ['Nintendo', 'THQ', 'Activision', 'Acclaim Entertainment', 'Video System', 'Electronic Arts', 'Namco Bandai Games', 'Ocean', 'Midway Games', 'Hudson Soft']
#
# PS ['Sony Computer Entertainment', 'SquareSoft', 'GT Interactive', 'Konami Digital Entertainment', 'Virgin Interactive', 'Eidos Interactive', 'Activision', 'Atari', 'Enix Corporation', 'Hasbro Interactive']
#
# XB ['Microsoft Game Studios', 'Ubisoft', 'Take-Two Interactive', 'Electronic Arts', 'Activision', 'Sega', 'Vivendi Games', 'Universal Interactive', 'Atari', 'Eidos Interactive']
#
# PC ['Electronic Arts', 'Activision', 'Microsoft Game Studios', 'Vivendi Games', 'Bethesda Softworks', 'Virgin Interactive', 'Red Orb', 'Hasbro Interactive', 'NCSoft', 'Eidos Interactive']
#
# 2600 ['Atari', 'Activision', 'Parker Bros.', 'Imagic', 'Coleco', 'Quelle', 'Mystique', '20th Century Fox Video Games', 'Men-A-Vision', 'Tigervision']
#
# PSP ['Take-Two Interactive', 'Capcom', 'Sony Computer Entertainment', 'Square Enix', 'Electronic Arts', 'Activision', 'Konami Digital Entertainment', 'LucasArts', 'Sega', 'Warner Bros. Interactive Entertainment']
#
# XOne ['Activision', 'Take-Two Interactive', 'Microsoft Game Studios', 'Bethesda Softworks', 'Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment', 'Square Enix', 'Namco Bandai Games', 'Konami Digital Entertainment']
#
# GC ['Nintendo', 'Sega', 'Infogrames', 'LucasArts', 'Capcom', 'Atari', 'Namco Bandai Games', 'Eidos Interactive', 'Electronic Arts', 'Activision']
#
# WiiU ['Nintendo', 'Ubisoft', 'Namco Bandai Games', 'Warner Bros. Interactive Entertainment', 'Activision', 'Disney Interactive Studios', 'Sega', 'Electronic Arts', 'Microsoft Game Studios', 'Square Enix']
#
# GEN ['Sega', 'Arena Entertainment', 'Virgin Interactive', 'Acclaim Entertainment', 'Capcom', 'Game Arts', 'Konami Digital Entertainment']
#
# DC ['Sega', 'Eidos Interactive', 'Namco Bandai Games', 'Virgin Interactive', 'Ubisoft', 'Genki', 'Acclaim Entertainment', 'Capcom', 'SNK', 'Activision']
#
# PSV ['Sony Computer Entertainment Europe', 'Sony Computer Entertainment', 'Activision', 'Ubisoft', 'Atlus', 'Electronic Arts', 'Square Enix', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment', 'Sega']
#
# SAT ['Sega', 'Compile', 'Banpresto', 'ESP', 'Namco Bandai Games', 'Atlus', 'Konami Digital Entertainment', 'Elf', 'Capcom', 'Virgin Interactive']
#
# SCD ['Sega']
#
# WS ['SquareSoft', 'Namco Bandai Games']
#
# NG ['SNK', 'Hudson Soft', 'Technos Japan Corporation']
#
# TG16 ['NEC', 'Hudson Soft']
#
# 3DO ['Konami Digital Entertainment', 'Micro Cabin', 'Imageworks']
#
# GG ['Sega']
#
# PCFX ['NEC']

# %% [markdown]
# FPGrowth

# %%
# !pip install pyfpgrowth

# %%
import pyfpgrowth

# %%
patterns = pyfpgrowth.find_frequent_patterns(data, 5)
for p,d in patterns.items():
    print(p,":",d)
# Out:
# ('LucasArts',) : 5
# ('LucasArts', 'Sega') : 5
# ('Microsoft Game Studios',) : 5
# ('Electronic Arts', 'Microsoft Game Studios') : 5
# ('Activision', 'Microsoft Game Studios') : 5
# ('Activision', 'Electronic Arts', 'Microsoft Game Studios') : 5
# ('Bethesda Softworks',) : 5
# ('Bethesda Softworks', 'Electronic Arts') : 5
# ('Activision', 'Bethesda Softworks') : 5
# ('Activision', 'Bethesda Softworks', 'Electronic Arts') : 5
# ('Atari',) : 5
# ('SquareSoft',) : 6
# ('Namco Bandai Games', 'SquareSoft') : 5
# ('Sony Computer Entertainment', 'Take-Two Interactive') : 5
# ('Activision', 'Sony Computer Entertainment', 'Take-Two Interactive') : 5
# ('Konami Digital Entertainment', 'Sony Computer Entertainment') : 5
# ('Activision', 'Konami Digital Entertainment', 'Sony Computer Entertainment') : 5
# ('Electronic Arts', 'Sony Computer Entertainment') : 5
# ('Electronic Arts', 'Sony Computer Entertainment', 'Take-Two Interactive') : 5
# ('Activision', 'Electronic Arts', 'Sony Computer Entertainment') : 5
# ('Activision', 'Electronic Arts', 'Sony Computer Entertainment', 'Take-Two Interactive') : 5
# ('Activision', 'Sony Computer Entertainment') : 6
# ('Virgin Interactive',) : 6
# ('Eidos Interactive',) : 7
# ('Eidos Interactive', 'Electronic Arts') : 5
# ('Activision', 'Eidos Interactive') : 7
# ('Activision', 'Eidos Interactive', 'Electronic Arts') : 5
# ('Konami Digital Entertainment', 'Take-Two Interactive') : 5
# ('Activision', 'Konami Digital Entertainment', 'Take-Two Interactive') : 5
# ('Electronic Arts', 'Konami Digital Entertainment', 'Take-Two Interactive') : 5
# ('Activision', 'Electronic Arts', 'Konami Digital Entertainment', 'Take-Two Interactive') : 5
# ('Take-Two Interactive', 'Warner Bros. Interactive Entertainment') : 7
# ('Activision', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment') : 7
# ('Electronic Arts', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment') : 7
# ('Activision', 'Electronic Arts', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment') : 7
# ('Take-Two Interactive', 'Ubisoft') : 7
# ('Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 6
# ('Activision', 'Take-Two Interactive', 'Ubisoft') : 7
# ('Electronic Arts', 'Take-Two Interactive', 'Ubisoft') : 7
# ('Activision', 'Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 6
# ('Electronic Arts', 'Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 6
# ('Activision', 'Electronic Arts', 'Take-Two Interactive', 'Ubisoft') : 7
# ('Activision', 'Electronic Arts', 'Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 6
# ('Electronic Arts', 'Take-Two Interactive') : 9
# ('Activision', 'Take-Two Interactive') : 9
# ('Activision', 'Electronic Arts', 'Take-Two Interactive') : 9
# ('Square Enix', 'Ubisoft') : 5
# ('Activision', 'Square Enix', 'Ubisoft') : 5
# ('Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 5
# ('Electronic Arts', 'Square Enix', 'Ubisoft') : 5
# ('Activision', 'Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 5
# ('Activision', 'Electronic Arts', 'Square Enix', 'Ubisoft') : 5
# ('Electronic Arts', 'Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 5
# ('Activision', 'Electronic Arts', 'Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 5
# ('Konami Digital Entertainment', 'Square Enix') : 5
# ('Electronic Arts', 'Konami Digital Entertainment', 'Square Enix') : 5
# ('Sega', 'Square Enix', 'Warner Bros. Interactive Entertainment') : 5
# ('Electronic Arts', 'Sega', 'Square Enix') : 5
# ('Square Enix', 'Warner Bros. Interactive Entertainment') : 7
# ('Electronic Arts', 'Square Enix', 'Warner Bros. Interactive Entertainment') : 6
# ('Activision', 'Square Enix') : 7
# ('Activision', 'Square Enix', 'Warner Bros. Interactive Entertainment') : 6
# ('Activision', 'Electronic Arts', 'Square Enix') : 7
# ('Activision', 'Electronic Arts', 'Square Enix', 'Warner Bros. Interactive Entertainment') : 6
# ('Electronic Arts', 'Square Enix') : 8
# ('Nintendo', 'Sega') : 6
# ('Electronic Arts', 'Nintendo', 'Sega') : 5
# ('Activision', 'Nintendo') : 6
# ('Activision', 'Electronic Arts', 'Nintendo') : 6
# ('Electronic Arts', 'Nintendo') : 7
# ('Electronic Arts', 'Namco Bandai Games', 'Nintendo') : 5
# ('Namco Bandai Games', 'Nintendo') : 7
# ('Sega', 'Ubisoft') : 6
# ('Electronic Arts', 'Sega', 'Ubisoft') : 5
# ('Activision', 'Sega', 'Ubisoft') : 6
# ('Activision', 'Electronic Arts', 'Sega', 'Ubisoft') : 5
# ('Electronic Arts', 'Ubisoft') : 9
# ('Activision', 'Electronic Arts', 'Ubisoft') : 9
# ('Activision', 'Ubisoft') : 10
# ('Sega', 'Warner Bros. Interactive Entertainment') : 6
# ('Activision', 'Sega', 'Warner Bros. Interactive Entertainment') : 5
# ('Electronic Arts', 'Sega', 'Warner Bros. Interactive Entertainment') : 5
# ('Activision', 'Electronic Arts', 'Sega', 'Warner Bros. Interactive Entertainment') : 5
# ('Ubisoft', 'Warner Bros. Interactive Entertainment') : 7
# ('Activision', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 7
# ('Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 7
# ('Activision', 'Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment') : 7
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment') : 9
# ('Activision', 'Warner Bros. Interactive Entertainment') : 9
# ('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment') : 9
# ('Capcom', 'Nintendo') : 5
# ('Capcom', 'Konami Digital Entertainment') : 5
# ('Activision', 'Capcom') : 5
# ('Capcom', 'Namco Bandai Games') : 6
# ('Capcom', 'Sega') : 6
# ('Konami Digital Entertainment', 'Namco Bandai Games') : 7
# ('Electronic Arts', 'Konami Digital Entertainment') : 7
# ('Electronic Arts', 'Konami Digital Entertainment', 'Namco Bandai Games') : 5
# ('Activision', 'Konami Digital Entertainment') : 7
# ('Activision', 'Electronic Arts', 'Konami Digital Entertainment') : 6
# ('Namco Bandai Games', 'Sega') : 5
# ('Electronic Arts', 'Namco Bandai Games') : 8
# ('Activision', 'Namco Bandai Games') : 8
# ('Activision', 'Electronic Arts', 'Namco Bandai Games') : 7
# ('Electronic Arts', 'Sega') : 8
# ('Activision', 'Sega') : 8
# ('Activision', 'Electronic Arts', 'Sega') : 7
# ('Electronic Arts',) : 16
# ('Activision', 'Electronic Arts') : 15
# ('Activision',) : 18

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 1.0)
for p,d in rules.items():
    print(p,"=>",d)
# Out:
# ('LucasArts',) => (('Sega',), 1.0)
# ('Microsoft Game Studios',) => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Microsoft Game Studios') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Microsoft Game Studios') => (('Activision',), 1.0)
# ('Bethesda Softworks',) => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Bethesda Softworks') => (('Electronic Arts',), 1.0)
# ('Bethesda Softworks', 'Electronic Arts') => (('Activision',), 1.0)
# ('Sony Computer Entertainment', 'Take-Two Interactive') => (('Activision', 'Electronic Arts'), 1.0)
# ('Konami Digital Entertainment', 'Sony Computer Entertainment') => (('Activision',), 1.0)
# ('Electronic Arts', 'Sony Computer Entertainment') => (('Activision', 'Take-Two Interactive'), 1.0)
# ('Activision', 'Electronic Arts', 'Sony Computer Entertainment') => (('Take-Two Interactive',), 1.0)
# ('Activision', 'Sony Computer Entertainment', 'Take-Two Interactive') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Sony Computer Entertainment', 'Take-Two Interactive') => (('Activision',), 1.0)
# ('Eidos Interactive',) => (('Activision',), 1.0)
# ('Eidos Interactive', 'Electronic Arts') => (('Activision',), 1.0)
# ('Konami Digital Entertainment', 'Take-Two Interactive') => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Konami Digital Entertainment', 'Take-Two Interactive') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Konami Digital Entertainment', 'Take-Two Interactive') => (('Activision',), 1.0)
# ('Take-Two Interactive', 'Warner Bros. Interactive Entertainment') => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Take-Two Interactive', 'Ubisoft') => (('Activision', 'Electronic Arts'), 1.0)
# ('Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Take-Two Interactive', 'Ubisoft') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Take-Two Interactive', 'Ubisoft') => (('Activision',), 1.0)
# ('Activision', 'Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Take-Two Interactive', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Activision', 'Take-Two Interactive') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Take-Two Interactive') => (('Activision',), 1.0)
# ('Square Enix', 'Ubisoft') => (('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment'), 1.0)
# ('Activision', 'Square Enix', 'Ubisoft') => (('Electronic Arts', 'Warner Bros. Interactive Entertainment'), 1.0)
# ('Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision', 'Electronic Arts'), 1.0)
# ('Electronic Arts', 'Square Enix', 'Ubisoft') => (('Activision', 'Warner Bros. Interactive Entertainment'), 1.0)
# ('Activision', 'Electronic Arts', 'Square Enix', 'Ubisoft') => (('Warner Bros. Interactive Entertainment',), 1.0)
# ('Activision', 'Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Square Enix', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Konami Digital Entertainment', 'Square Enix') => (('Electronic Arts',), 1.0)
# ('Activision', 'Square Enix') => (('Electronic Arts',), 1.0)
# ('Activision', 'Square Enix', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Square Enix', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Activision', 'Nintendo') => (('Electronic Arts',), 1.0)
# ('Sega', 'Ubisoft') => (('Activision',), 1.0)
# ('Electronic Arts', 'Sega', 'Ubisoft') => (('Activision',), 1.0)
# ('Electronic Arts', 'Ubisoft') => (('Activision',), 1.0)
# ('Activision', 'Sega', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Sega', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision', 'Electronic Arts'), 1.0)
# ('Activision', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)
# ('Activision', 'Warner Bros. Interactive Entertainment') => (('Electronic Arts',), 1.0)
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment') => (('Activision',), 1.0)

# %% [markdown]
# Apriori

# %%
# !pip install efficient_apriori

# %%
from efficient_apriori import apriori

# %%
itemsets, rules = apriori(data, min_support=0.2,  min_confidence=0.2)

# %%
hasil = []
for x in rules:
    hasil.append([str(x.lhs)+"=>"+str(x.rhs),x.support,x.confidence,x.lift,x.conviction])
    print(str(x.lhs)+"=>"+str(x.rhs),x.support,x.confidence,x.lift,x.conviction,sep="\t")
# Out:
# ('Eidos Interactive',)=>('Activision',)	0.22580645161290322	1.0	1.722222222222222	419354838.70967734
# ('Activision',)=>('Eidos Interactive',)	0.22580645161290322	0.3888888888888889	1.722222222222222	1.2668621680149292
# ('Electronic Arts',)=>('Activision',)	0.4838709677419355	0.9375	1.6145833333333335	6.709677312000001
# ('Activision',)=>('Electronic Arts',)	0.4838709677419355	0.8333333333333334	1.6145833333333335	2.903225789032259
# ('Konami Digital Entertainment',)=>('Activision',)	0.22580645161290322	0.5833333333333334	1.0046296296296295	1.006451610487742
# ('Activision',)=>('Konami Digital Entertainment',)	0.22580645161290322	0.3888888888888889	1.0046296296296295	1.0029325496784858
# ('Namco Bandai Games',)=>('Activision',)	0.25806451612903225	0.6153846153846154	1.0598290598290598	1.0903225778103225
# ('Activision',)=>('Namco Bandai Games',)	0.25806451612903225	0.4444444444444444	1.0598290598290598	1.0451612884412902
# ('Sega',)=>('Activision',)	0.25806451612903225	0.5714285714285714	0.9841269841269841	0.9784946213727597
# ('Activision',)=>('Sega',)	0.25806451612903225	0.4444444444444444	0.9841269841269841	0.9870967724167741
# ('Square Enix',)=>('Activision',)	0.22580645161290322	0.7777777777777778	1.3395061728395061	1.8870967657016129
# ('Activision',)=>('Square Enix',)	0.22580645161290322	0.3888888888888889	1.3395061728395061	1.161290320680352
# ('Take-Two Interactive',)=>('Activision',)	0.2903225806451613	1.0	1.7222222222222223	419354838.70967734
# ('Activision',)=>('Take-Two Interactive',)	0.2903225806451613	0.5	1.7222222222222223	1.419354835870968
# ('Ubisoft',)=>('Activision',)	0.3225806451612903	1.0	1.722222222222222	419354838.70967734
# ('Activision',)=>('Ubisoft',)	0.3225806451612903	0.5555555555555556	1.722222222222222	1.5241935449576614
# ('Warner Bros. Interactive Entertainment',)=>('Activision',)	0.2903225806451613	0.9	1.55	4.193548345161291
# ('Activision',)=>('Warner Bros. Interactive Entertainment',)	0.2903225806451613	0.5	1.55	1.3548387069677421
# ('Konami Digital Entertainment',)=>('Electronic Arts',)	0.22580645161290322	0.5833333333333334	1.1302083333333333	1.1612903197935485
# ('Electronic Arts',)=>('Konami Digital Entertainment',)	0.22580645161290322	0.4375	1.1302083333333333	1.0896057328299482
# ('Namco Bandai Games',)=>('Electronic Arts',)	0.25806451612903225	0.6153846153846154	1.1923076923076923	1.2580645128580645
# ('Electronic Arts',)=>('Namco Bandai Games',)	0.25806451612903225	0.5	1.1923076923076923	1.1612903202580644
# ('Nintendo',)=>('Electronic Arts',)	0.22580645161290322	0.7	1.35625	1.6129032204301073
# ('Electronic Arts',)=>('Nintendo',)	0.22580645161290322	0.4375	1.35625	1.2043010731278376
# ('Sega',)=>('Electronic Arts',)	0.25806451612903225	0.5714285714285714	1.107142857142857	1.1290322554301073
# ('Electronic Arts',)=>('Sega',)	0.25806451612903225	0.5	1.107142857142857	1.0967741913548388
# ('Square Enix',)=>('Electronic Arts',)	0.25806451612903225	0.8888888888888888	1.7222222222222223	4.354838670483869
# ('Electronic Arts',)=>('Square Enix',)	0.25806451612903225	0.5	1.7222222222222223	1.419354835870968
# ('Take-Two Interactive',)=>('Electronic Arts',)	0.2903225806451613	1.0	1.9375000000000002	483870967.7419355
# ('Electronic Arts',)=>('Take-Two Interactive',)	0.2903225806451613	0.5625	1.9375000000000002	1.6221198119605003
# ('Ubisoft',)=>('Electronic Arts',)	0.2903225806451613	0.9	1.7437500000000001	4.83870962903226
# ('Electronic Arts',)=>('Ubisoft',)	0.2903225806451613	0.5625	1.7437500000000001	1.548387093235023
# ('Warner Bros. Interactive Entertainment',)=>('Electronic Arts',)	0.2903225806451613	0.9	1.7437500000000001	4.83870962903226
# ('Electronic Arts',)=>('Warner Bros. Interactive Entertainment',)	0.2903225806451613	0.5625	1.7437500000000001	1.548387093235023
# ('Namco Bandai Games',)=>('Konami Digital Entertainment',)	0.22580645161290322	0.5384615384615384	1.391025641025641	1.3279569863700715
# ('Konami Digital Entertainment',)=>('Namco Bandai Games',)	0.22580645161290322	0.5833333333333334	1.391025641025641	1.393548383752258
# ('Nintendo',)=>('Namco Bandai Games',)	0.22580645161290322	0.7	1.6692307692307693	1.9354838645161283
# ('Namco Bandai Games',)=>('Nintendo',)	0.22580645161290322	0.5384615384615384	1.6692307692307693	1.4677419323037635
# ('Warner Bros. Interactive Entertainment',)=>('Square Enix',)	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Square Enix',)=>('Warner Bros. Interactive Entertainment',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Ubisoft',)=>('Take-Two Interactive',)	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Ubisoft',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Warner Bros. Interactive Entertainment',)=>('Take-Two Interactive',)	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Warner Bros. Interactive Entertainment',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Warner Bros. Interactive Entertainment',)=>('Ubisoft',)	0.25806451612903225	0.8	2.48	3.3870967572580657
# ('Ubisoft',)=>('Warner Bros. Interactive Entertainment',)	0.25806451612903225	0.8	2.48	3.3870967572580657
# ('Electronic Arts', 'Namco Bandai Games')=>('Activision',)	0.22580645161290322	0.875	1.5069444444444444	3.3548386828387096
# ('Activision', 'Namco Bandai Games')=>('Electronic Arts',)	0.22580645161290322	0.875	1.6953124999999998	3.8709677109677423
# ('Activision', 'Electronic Arts')=>('Namco Bandai Games',)	0.22580645161290322	0.4666666666666667	1.1128205128205129	1.088709675378024
# ('Namco Bandai Games',)=>('Activision', 'Electronic Arts')	0.22580645161290322	0.5384615384615384	1.1128205128205129	1.1182795674695338
# ('Electronic Arts',)=>('Activision', 'Namco Bandai Games')	0.22580645161290322	0.4375	1.6953124999999998	1.3189964134257268
# ('Activision',)=>('Electronic Arts', 'Namco Bandai Games')	0.22580645161290322	0.3888888888888889	1.5069444444444444	1.2140762443476405
# ('Electronic Arts', 'Sega')=>('Activision',)	0.22580645161290322	0.875	1.5069444444444444	3.3548386828387096
# ('Activision', 'Sega')=>('Electronic Arts',)	0.22580645161290322	0.875	1.6953124999999998	3.8709677109677423
# ('Activision', 'Electronic Arts')=>('Sega',)	0.22580645161290322	0.4666666666666667	1.0333333333333332	1.0282258045236896
# ('Sega',)=>('Activision', 'Electronic Arts')	0.22580645161290322	0.5	1.0333333333333332	1.032258062451613
# ('Electronic Arts',)=>('Activision', 'Sega')	0.22580645161290322	0.4375	1.6953124999999998	1.3189964134257268
# ('Activision',)=>('Electronic Arts', 'Sega')	0.22580645161290322	0.3888888888888889	1.5069444444444444	1.2140762443476405
# ('Electronic Arts', 'Square Enix')=>('Activision',)	0.22580645161290322	0.875	1.5069444444444444	3.3548386828387096
# ('Activision', 'Square Enix')=>('Electronic Arts',)	0.22580645161290322	1.0	1.9374999999999998	483870967.7419355
# ('Activision', 'Electronic Arts')=>('Square Enix',)	0.22580645161290322	0.4666666666666667	1.6074074074074074	1.3306451587953632
# ('Square Enix',)=>('Activision', 'Electronic Arts')	0.22580645161290322	0.7777777777777778	1.6074074074074074	2.3225806347096776
# ('Electronic Arts',)=>('Activision', 'Square Enix')	0.22580645161290322	0.4375	1.9374999999999998	1.3763440835746714
# ('Activision',)=>('Electronic Arts', 'Square Enix')	0.22580645161290322	0.3888888888888889	1.5069444444444444	1.2140762443476405
# ('Electronic Arts', 'Take-Two Interactive')=>('Activision',)	0.2903225806451613	1.0	1.7222222222222223	419354838.70967734
# ('Activision', 'Take-Two Interactive')=>('Electronic Arts',)	0.2903225806451613	1.0	1.9375000000000002	483870967.7419355
# ('Activision', 'Electronic Arts')=>('Take-Two Interactive',)	0.2903225806451613	0.6	2.066666666666667	1.7741935439516128
# ('Take-Two Interactive',)=>('Activision', 'Electronic Arts')	0.2903225806451613	1.0	2.066666666666667	516129032.25806445
# ('Electronic Arts',)=>('Activision', 'Take-Two Interactive')	0.2903225806451613	0.5625	1.9375000000000002	1.6221198119605003
# ('Activision',)=>('Electronic Arts', 'Take-Two Interactive')	0.2903225806451613	0.5	1.7222222222222223	1.419354835870968
# ('Electronic Arts', 'Ubisoft')=>('Activision',)	0.2903225806451613	1.0	1.7222222222222223	419354838.70967734
# ('Activision', 'Ubisoft')=>('Electronic Arts',)	0.2903225806451613	0.9	1.7437500000000001	4.83870962903226
# ('Activision', 'Electronic Arts')=>('Ubisoft',)	0.2903225806451613	0.6	1.8600000000000003	1.6935483828629032
# ('Ubisoft',)=>('Activision', 'Electronic Arts')	0.2903225806451613	0.9	1.8600000000000003	5.1612902709677435
# ('Electronic Arts',)=>('Activision', 'Ubisoft')	0.2903225806451613	0.5625	1.7437500000000001	1.548387093235023
# ('Activision',)=>('Electronic Arts', 'Ubisoft')	0.2903225806451613	0.5	1.7222222222222223	1.419354835870968
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Activision',)	0.2903225806451613	1.0	1.7222222222222223	419354838.70967734
# ('Activision', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts',)	0.2903225806451613	1.0	1.9375000000000002	483870967.7419355
# ('Activision', 'Electronic Arts')=>('Warner Bros. Interactive Entertainment',)	0.2903225806451613	0.6	1.8600000000000003	1.6935483828629032
# ('Warner Bros. Interactive Entertainment',)=>('Activision', 'Electronic Arts')	0.2903225806451613	0.9	1.8600000000000003	5.1612902709677435
# ('Electronic Arts',)=>('Activision', 'Warner Bros. Interactive Entertainment')	0.2903225806451613	0.5625	1.9375000000000002	1.6221198119605003
# ('Activision',)=>('Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.2903225806451613	0.5	1.7222222222222223	1.419354835870968
# ('Take-Two Interactive', 'Ubisoft')=>('Activision',)	0.22580645161290322	1.0	1.722222222222222	419354838.70967734
# ('Activision', 'Ubisoft')=>('Take-Two Interactive',)	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Activision', 'Take-Two Interactive')=>('Ubisoft',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Ubisoft',)=>('Activision', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Activision', 'Ubisoft')	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Activision',)=>('Take-Two Interactive', 'Ubisoft')	0.22580645161290322	0.3888888888888889	1.722222222222222	1.2668621680149292
# ('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')=>('Activision',)	0.22580645161290322	1.0	1.722222222222222	419354838.70967734
# ('Activision', 'Warner Bros. Interactive Entertainment')=>('Take-Two Interactive',)	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Take-Two Interactive')=>('Warner Bros. Interactive Entertainment',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Warner Bros. Interactive Entertainment',)=>('Activision', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Activision', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision',)=>('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.3888888888888889	1.722222222222222	1.2668621680149292
# ('Ubisoft', 'Warner Bros. Interactive Entertainment')=>('Activision',)	0.25806451612903225	1.0	1.7222222222222223	419354838.70967734
# ('Activision', 'Warner Bros. Interactive Entertainment')=>('Ubisoft',)	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Activision', 'Ubisoft')=>('Warner Bros. Interactive Entertainment',)	0.25806451612903225	0.8	2.48	3.3870967572580657
# ('Warner Bros. Interactive Entertainment',)=>('Activision', 'Ubisoft')	0.25806451612903225	0.8	2.48	3.3870967572580657
# ('Ubisoft',)=>('Activision', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Activision',)=>('Ubisoft', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.4444444444444444	1.7222222222222223	1.335483868563871
# ('Take-Two Interactive', 'Ubisoft')=>('Electronic Arts',)	0.22580645161290322	1.0	1.9374999999999998	483870967.7419355
# ('Electronic Arts', 'Ubisoft')=>('Take-Two Interactive',)	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts', 'Take-Two Interactive')=>('Ubisoft',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Ubisoft',)=>('Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Electronic Arts', 'Ubisoft')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts',)=>('Take-Two Interactive', 'Ubisoft')	0.22580645161290322	0.4375	1.9374999999999998	1.3763440835746714
# ('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts',)	0.22580645161290322	1.0	1.9374999999999998	483870967.7419355
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Take-Two Interactive',)	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts', 'Take-Two Interactive')=>('Warner Bros. Interactive Entertainment',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Warner Bros. Interactive Entertainment',)=>('Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts',)=>('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.4375	1.9374999999999998	1.3763440835746714
# ('Ubisoft', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts',)	0.25806451612903225	1.0	1.9374999999999998	483870967.7419355
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Ubisoft',)	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Electronic Arts', 'Ubisoft')=>('Warner Bros. Interactive Entertainment',)	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Warner Bros. Interactive Entertainment',)=>('Electronic Arts', 'Ubisoft')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Ubisoft',)=>('Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Electronic Arts',)=>('Ubisoft', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.5	1.9374999999999998	1.4838709647741937
# ('Electronic Arts', 'Take-Two Interactive', 'Ubisoft')=>('Activision',)	0.22580645161290322	1.0	1.722222222222222	419354838.70967734
# ('Activision', 'Take-Two Interactive', 'Ubisoft')=>('Electronic Arts',)	0.22580645161290322	1.0	1.9374999999999998	483870967.7419355
# ('Activision', 'Electronic Arts', 'Ubisoft')=>('Take-Two Interactive',)	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Electronic Arts', 'Take-Two Interactive')=>('Ubisoft',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Take-Two Interactive', 'Ubisoft')=>('Activision', 'Electronic Arts')	0.22580645161290322	1.0	2.0666666666666664	516129032.25806445
# ('Electronic Arts', 'Ubisoft')=>('Activision', 'Take-Two Interactive')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts', 'Take-Two Interactive')=>('Activision', 'Ubisoft')	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Activision', 'Ubisoft')=>('Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Activision', 'Take-Two Interactive')=>('Electronic Arts', 'Ubisoft')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Electronic Arts')=>('Take-Two Interactive', 'Ubisoft')	0.22580645161290322	0.4666666666666667	2.0666666666666664	1.4516129005040324
# ('Ubisoft',)=>('Activision', 'Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Activision', 'Electronic Arts', 'Ubisoft')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts',)=>('Activision', 'Take-Two Interactive', 'Ubisoft')	0.22580645161290322	0.4375	1.9374999999999998	1.3763440835746714
# ('Activision',)=>('Electronic Arts', 'Take-Two Interactive', 'Ubisoft')	0.22580645161290322	0.3888888888888889	1.722222222222222	1.2668621680149292
# ('Electronic Arts', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment')=>('Activision',)	0.22580645161290322	1.0	1.722222222222222	419354838.70967734
# ('Activision', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts',)	0.22580645161290322	1.0	1.9374999999999998	483870967.7419355
# ('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Take-Two Interactive',)	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Electronic Arts', 'Take-Two Interactive')=>('Warner Bros. Interactive Entertainment',)	0.22580645161290322	0.7777777777777778	2.411111111111111	3.0483870830564523
# ('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')=>('Activision', 'Electronic Arts')	0.22580645161290322	1.0	2.0666666666666664	516129032.25806445
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Activision', 'Take-Two Interactive')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts', 'Take-Two Interactive')=>('Activision', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Take-Two Interactive')=>('Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Activision', 'Electronic Arts')=>('Take-Two Interactive', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.4666666666666667	2.0666666666666664	1.4516129005040324
# ('Warner Bros. Interactive Entertainment',)=>('Activision', 'Electronic Arts', 'Take-Two Interactive')	0.22580645161290322	0.7	2.411111111111111	2.365591389964157
# ('Take-Two Interactive',)=>('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.7777777777777778	2.6790123456790123	3.193548372725807
# ('Electronic Arts',)=>('Activision', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.4375	1.9374999999999998	1.3763440835746714
# ('Activision',)=>('Electronic Arts', 'Take-Two Interactive', 'Warner Bros. Interactive Entertainment')	0.22580645161290322	0.3888888888888889	1.722222222222222	1.2668621680149292
# ('Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment')=>('Activision',)	0.25806451612903225	1.0	1.7222222222222223	419354838.70967734
# ('Activision', 'Ubisoft', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts',)	0.25806451612903225	1.0	1.9374999999999998	483870967.7419355
# ('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Ubisoft',)	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Activision', 'Electronic Arts', 'Ubisoft')=>('Warner Bros. Interactive Entertainment',)	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Ubisoft', 'Warner Bros. Interactive Entertainment')=>('Activision', 'Electronic Arts')	0.25806451612903225	1.0	2.066666666666667	516129032.25806445
# ('Electronic Arts', 'Warner Bros. Interactive Entertainment')=>('Activision', 'Ubisoft')	0.25806451612903225	0.8888888888888888	2.7555555555555555	6.096774138677418
# ('Electronic Arts', 'Ubisoft')=>('Activision', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.8888888888888888	3.0617283950617282	6.387096716709675
# ('Activision', 'Warner Bros. Interactive Entertainment')=>('Electronic Arts', 'Ubisoft')	0.25806451612903225	0.8888888888888888	3.0617283950617282	6.387096716709675
# ('Activision', 'Ubisoft')=>('Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Activision', 'Electronic Arts')=>('Ubisoft', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.5333333333333333	2.066666666666667	1.589861747745227
# ('Warner Bros. Interactive Entertainment',)=>('Activision', 'Electronic Arts', 'Ubisoft')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Ubisoft',)=>('Activision', 'Electronic Arts', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.8	2.7555555555555555	3.548387079032259
# ('Electronic Arts',)=>('Activision', 'Ubisoft', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.5	1.9374999999999998	1.4838709647741937
# ('Activision',)=>('Electronic Arts', 'Ubisoft', 'Warner Bros. Interactive Entertainment')	0.25806451612903225	0.4444444444444444	1.7222222222222223	1.335483868563871
